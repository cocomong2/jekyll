# %%
import os
import sys
import urllib.request
client_id = "K9qoz59BqEmEp3Itsjlz"
client_secret = "K4GeJ9ZLxP"
encText = urllib.parse.quote("메이플스토리2")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Mon, 21 Oct 2024 17:29:43 +0900",
# 	"total":31963,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>메이플스토리2<\/b>) 메콩 포스팅 최초 댓글러 &quot;구공&quot;님과... ",
# 			"link":"https:\/\/blog.naver.com\/rhdiddl7942\/223321707271",
# 			"description":"그런 정신병자도 즐길 수 있는 게임이 바로 <b>메이플스토리2<\/b> 입니다. 많은 사랑 부탁드립니다. 아 요녀석... 근데 이분 2015년 8월 6일 메이플 스포츠 뉴스에 나와있다. 닉변을 종종 했다고 하셔서 프라이버시를... ",
# 			"bloggername":"어느 화창한 날의 창",
# 			"bloggerlink":"blog.naver.com\/rhdiddl7942",
# 			"postdate":"20240114"
# 		},
# 		{
# 			"title":"<b>메이플스토리2<\/b> D0000 오류 해결방법, 원인은 PC 게임 패드... ",
# 			"link":"https:\/\/blog.naver.com\/kkb031\/223531612710",
# 			"description":"이런 2.5D MMORPG는 패드로 하려고 하시는 분들도 많을 것 같은데, 매크로를 방어하기 위해 이 유저풀을 포기하는게 맞는 운영정책인가 하는 의구심도 드네요. 여기까지 <b>메이플스토리2<\/b> D0000 오류 해결 방법에... ",
# 			"bloggername":"B플러스",
# 			"bloggerlink":"blog.naver.com\/kkb031",
# 			"postdate":"20240731"
# 		},
# 		{
# 			"title":"<b>메이플스토리2<\/b> 직업 소개 및 특징 정리",
# ...

# %%
import os
import sys
import urllib.request
client_id = "1148352"
client_secret = "74a779368cf2713c3d5a3cc365f45edf"
encText = urllib.parse.quote("설현")
url = "https://dapi.kakao.com/v2/search/image?query={0}".format(encText)
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("Authorization", "KakaoAK " +client_id)
request.add_header("Authorization", "KakaoAK " +client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {"documents":[{"collection":"news","datetime":"2021-09-14T23:45:22.000+09:00","display_sitename":"스포츠한국","doc_url":"http://v.media.daum.net/v/20210914234522455","height":540,"image_url":"https://t1.daumcdn.net/news/202109/14/SpoHankook/20210914234523497qmdp.jpg","thumbnail_url":"https://search1.kakaocdn.net/argon/130x130_85_c/4VPSdfN4KtR","width":540},{"collection":"news","datetime":"2024-04-13T14:35:41.000+09:00","display_sitename":"뉴스1","doc_url":"http://v.media.daum.net/v/20240413143541627","height":747,"image_url":"https://t1.daumcdn.net/news/202404/13/NEWS1/20240413143544341ogqk.jpg","thumbnail_url":"https://search4.kakaocdn.net/argon/130x130_85_c/H1Yxn0p2PQJ","width":594},{"collection":"news","datetime":"2024-09-11T14:06:12.000+09:00","display_sitename":"머니S","doc_url":"http://v.media.daum.net/v/20240911140612357","height":849,"image_url":"https://t1.daumcdn.net/news/202409/11/moneyweek/20240911140614153qaqr.jpg","thumbnail_url":"https://search4.kakaocdn.net/argon/130x130_85_c/
# ...

# %%
'1번 {0}, 2번 {1}'.format('테스트', '연습')
# Out:
# '1번 테스트, 2번 연습'

# %%
import os
import sys
import urllib.request # 웹 요청을 전송하고 응답을 수신하는 모듈 (브라우저 역할)

# 서버로 전송하는 데이터
client_id = "K9qoz59BqEmEp3Itsjlz"
client_secret = "K4GeJ9ZLxP"
encText = urllib.parse.quote("소년이 온다")

# 요청 url + get 방식 전송 데이터 구성 
url = "https://openapi.naver.com/v1/search/blog?query={0}&display={1}".format(encText, 50) 
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과


# header에 전송 데이터를 저장 
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request) # 요청 보내기 + 응답 수신 

rescode = response.getcode()  # 응답코드 읽기
if(rescode==200): # 정상 응답이라면 
    response_body = response.read() # 응답 데이터 읽기 
    print(response_body.decode('utf-8')) # Binary Data 를 utf-8  text 데이터로 변환 
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Tue, 22 Oct 2024 10:17:30 +0900",
# 	"total":137862,
# 	"start":1,
# 	"display":50,
# 	"items":[
# 		{
# 			"title":"한강 <b>소년이 온다<\/b> 줄거리 내용 광주 민주화 운동 518 책 리뷰",
# 			"link":"https:\/\/blog.naver.com\/xoxo6514\/223621644803",
# 			"description":"한강 <b>소년이 온다<\/b> 책 리뷰 광주 민주화운동 518 기억을 함께해요 <b>소년이 온다<\/b> 저자 한강 출판 창비 발매... 15세 소년 동호! 광주에서 일어난 민주화운동의 참상을 그대로 목격했습니다 그는 실종된 친구를... ",
# 			"bloggername":"부산블로거 도로시 블로그",
# 			"bloggerlink":"blog.naver.com\/xoxo6514",
# 			"postdate":"20241016"
# 		},
# 		{
# 			"title":"한강 <b>소년이 온다<\/b> 줄거리 내용 결말 해석",
# 			"link":"https:\/\/blog.naver.com\/bloodmark\/223616446013",
# 			"description":"중3의 소년이다. 동호는 타인의 고통을 그냥 지나가지 못하는 선한 인물인데 이는 우리 내면에 있는... 또 이는 소설의 제목인 '<b>소년이 온다<\/b>'와도 직통한다. 보시다시피 제목의 '온다' 현재형이다. 이는 과거는... ",
# 			"bloggername":"블마의 리뷰일상",
# 			"bloggerlink":"blog.naver.com\/bloodmark",
# 			"postdate":"20241012"
# 		},
# 		{
# 			"title":"노벨문학상 한강 「<b>소년이 온다<\/b>」 줄거리와 감상평",
# ...

# %%
text_response = response_body.decode('utf-8')

# %%
type(text_response)
# Out:
# str

# %%
# json str -> dict  딕셔너리로 바꾸기 위해서 
import json 

dict_response = json.loads(text_response)


print(type ( dict_response))
# print(dict_response) 무조건 print 넣어줘야 함 
# for item in dict_response['items']:

print (type(dict_response['items'])) #타입은 리스트를 뽑아줌 

for idx, item in enumerate(dict_response['items']): #enumerate 순차적으로 나열 
# print(type(item)) # item의 정체가 먼지 출력

    print("{0}. {1}".format(idx + 1, item['title']))
# Out:
# <class 'dict'>
# <class 'list'>
# 1. 한강 <b>소년이 온다</b> 줄거리 내용 광주 민주화 운동 518 책 리뷰
# 2. 한강 <b>소년이 온다</b> 줄거리 내용 결말 해석
# 3. 노벨문학상 한강 「<b>소년이 온다</b>」 줄거리와 감상평
# 4. (소설) <b>소년이 온다</b>
# 5. 2024 노벨문학상 한강 작가님의 채식주의자,<b>소년이 온다</b>...
# 6. &lt;<b>소년이 온다</b>&gt; 33인이 돌아가며 읽다
# 7. 독후감 한강 <b>소년이온다</b> 책리뷰 책소개
# 8. 독서기록 #111, <b>소년이 온다</b>(한강, 창비)
# 9. 실화 바탕의 소설추천 한강작가의 <b>소년이 온다</b>
# 10. 작별하지 않는다, 흰, 서랍에 저녁을 넣어 두었다, <b>소년이 온다</b>
# 11. <b>소년이 온다</b> 줄거리와 심층 분석 작가 한강의 대표작
# 12. 한강 작가 <b>소년이 온다</b> 줄거리 소설 내용
# 13. 한강 <b>소년이 온다</b> 줄거리 완벽 정리! 동호의 충격적인 결말은?
# 14. 한강 <b>소년이 온다</b> 줄거리 독서록 독후감상문
# 15. 노벨문학상 수상! 『<b>소년이 온다</b>』로 한국 문학의 새 역사를 쓰다
# 16. <b>소년이 온다</b>, 한강
# 17. 한강 노벨문학상 수상작 '<b>소년이 온다</b>' 줄거리와 등장인물 이야기
# 18. jpg (노벨상 수상작은 따로 없지만 <b>소년이 온다</b>가  큰 역할...
# 19. 현대문학 작가 기획전 - 한강 (<b>소년이 온다</b>/작별하지 않는다)
# 20. 기록 스페셜 포토덤프(급류, 작별하지 않는다, <b>소년이 온다</b> 등)
# 21. 한강 <b>소년이 온다</b> 내용 줄거리 해석 결말 책 대표작 feat....
# 22. <b>소년이 온다</b> 줄거리
# 23. '노벨 평화상의 소설, &quot;<b>소년이 온다</b>&quot; ...,,, 그리고 엄마의 눈물'
# ...

# %%
#titles = []
#for idx, item in enumerate(dict_response['items']):
#    titles.append(item['title])

titles = [item['title'] for item in dict_response['items']]
print(titles)
# Out:
# ['한강 <b>소년이 온다</b> 줄거리 내용 광주 민주화 운동 518 책 리뷰', '한강 <b>소년이 온다</b> 줄거리 내용 결말 해석', '노벨문학상 한강 「<b>소년이 온다</b>」 줄거리와 감상평', '(소설) <b>소년이 온다</b>', '2024 노벨문학상 한강 작가님의 채식주의자,<b>소년이 온다</b>... ', '&lt;<b>소년이 온다</b>&gt; 33인이 돌아가며 읽다', '독후감 한강 <b>소년이온다</b> 책리뷰 책소개', '독서기록 #111, <b>소년이 온다</b>(한강, 창비)', '실화 바탕의 소설추천 한강작가의 <b>소년이 온다</b>', '작별하지 않는다, 흰, 서랍에 저녁을 넣어 두었다, <b>소년이 온다</b>', '<b>소년이 온다</b> 줄거리와 심층 분석 작가 한강의 대표작', '한강 작가 <b>소년이 온다</b> 줄거리 소설 내용', '한강 <b>소년이 온다</b> 줄거리 완벽 정리! 동호의 충격적인 결말은?', '한강 <b>소년이 온다</b> 줄거리 독서록 독후감상문', '노벨문학상 수상! 『<b>소년이 온다</b>』로 한국 문학의 새 역사를 쓰다', '<b>소년이 온다</b>, 한강', "한강 노벨문학상 수상작 '<b>소년이 온다</b>' 줄거리와 등장인물 이야기", 'jpg (노벨상 수상작은 따로 없지만 <b>소년이 온다</b>가  큰 역할... ', '현대문학 작가 기획전 - 한강 (<b>소년이 온다</b>/작별하지 않는다)', '기록 스페셜 포토덤프(급류, 작별하지 않는다, <b>소년이 온다</b> 등)', '한강 <b>소년이 온다</b> 내용 줄거리 해석 결말 책 대표작 feat.... ', '<b>소년이 온다</b> 줄거리', "'노벨 평화상의 소설, &quot;<b>소년이 온다</b>&quot; ...,,, 그리고 엄마의 눈물'", '&lt;<b>소년이 온다</b>&gt;를 보다.', '한강,&lt;흰&gt;, &lt;채식주의자&gt;, &lt;<b>소년이 온다</b>&gt;(작성중)', '<b
# ...

# %%
# 딕셔너리
# dict : key : value
lv = ['abc', 'xyz',' pqr']
dv = { 1: 'abc', 2: 'xyz', 3: 'pqr'}
dv2 = {'11': 'abc', '22':'xyz','33':'pqr'}

print( lv[0]) # list 에서 데이터 읽기 lv[0] 리스트는 순서 번호로 읽는게 맞음 
print( dv[1]) #dict에서 데이터 읽기 dv[1]은 순서번호 읽는게 아닌 키 번호로 읽는거다
print(dv2['11']) #dict 에서 데이터 읽기 (키)
print( dict_response.keys())
# Out:
# abc
# abc
# abc
# dict_keys(['lastBuildDate', 'total', 'start', 'display', 'items'])

# %%
! pip install pandas
# Out:
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# keras 3.6.0 requires h5py, which is not installed.
# keras 3.6.0 requires rich, which is not installed.
# tensorboard 2.17.1 requires markdown>=2.6.8, which is not installed.
# tensorboard 2.17.1 requires protobuf!=4.24.0,>=3.19.6, which is not installed.
# tensorboard 2.17.1 requires werkzeug>=1.0.1, which is not installed.
# tensorflow-intel 2.17.0 requires h5py>=3.10.0, which is not installed.
# tensorflow-intel 2.17.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, which is not installed.
# tensorflow-intel 2.17.0 requires wrapt>=1.11.0, which is not installed.
# tensorflow-intel 2.17.0 requires numpy<2.0.0,>=1.26.0; python_version >= "3.12", but you have numpy 2.1.2 which is incompatible.
# ...
#   Using cached pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# ...

# %%
import pandas as pd # 판다스는 기본 모듈이 아님 그래서 설치 후에 실행해야 됨

# %%
df_response = pd.DataFrame(dict_response['items'])
print(type(df_response))   # 타입확인
# Out:
# <class 'pandas.core.frame.DataFrame'>
